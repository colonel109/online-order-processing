# %%
import pandas as pd
from pathlib import Path
import duckdb
from openpyxl.writer.excel import ExcelWriter
from pandas.core.methods.to_dict import to_dict

# %%
folder_path = Path(r"E:\online-order-processing\samples\shopee")

# %%
order_shopee = Path(folder_path / "đơn tải sàn.xlsx")
output_shopee = Path(folder_path / "file output.xlsx")
code_shopee = Path(folder_path / "SHOPEE CODE.xlsm")
runner_shopee = Path(folder_path / "file chạy.xlsx")

# %%
order_df = pd.read_excel(order_shopee, dtype="string")
output_df = pd.read_excel(output_shopee, sheet_name="PXKDH", skiprows=8, dtype="string")
code_df = pd.read_excel(code_shopee, sheet_name="CODE")
runner_df = pd.read_excel(runner_shopee)
